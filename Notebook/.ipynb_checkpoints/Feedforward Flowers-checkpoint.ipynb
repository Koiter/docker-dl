# %%
from __future__ import absolute_import, division, print_function

import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub
import os

from tensorflow.keras import layers

tf.VERSION
# Out:
# '1.13.1'

# %%
data_root = tf.keras.utils.get_file(
  'flower_photos','https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
   untar=True)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 17s 0us/step

# %% [markdown]
# ##### Pre processing

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1/255)
image_data = image_generator.flow_from_directory(str(data_root))
# Out:
# Found 3670 images belonging to 5 classes.

# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step

# %% [markdown]
# ##### Not part of totorial

# %%
os.listdir(data_root)
# Out:
# ['LICENSE.txt', 'sunflowers', 'tulips', 'dandelion', 'daisy', 'roses']

# %%
print(data_root)
# Out:
# /home/jovyan/.keras/datasets/flower_photos

# %%
from IPython.display import Image
Image(data_root +'/sunflowers/7820398908_4316bbba45.jpg')

# %%
for image_batch,label_batch in image_data:
  print("Image batch shape: ", image_batch.shape)
  print("Label batch shape: ", label_batch.shape)
  break
# Out:
# Image batch shape:  (32, 224, 224, 3)
# Label batch shape:  (32, 5)

# %%
from matplotlib import pyplot as plt
plt.imshow(image_batch[31,:,:,:], interpolation='nearest')
plt.show()

# %% [markdown]
# ###### Until here

# %%
classifier_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/classification/2" #@param {type:"string"}
def classifier(x):
  classifier_module = hub.Module(classifier_url)
  return classifier_module(x)
  
IMAGE_SIZE = hub.get_expected_image_size(hub.Module(classifier_url))

# %%
classifier_layer = layers.Lambda(classifier, input_shape = IMAGE_SIZE+[3])
classifier_model = tf.keras.Sequential([classifier_layer])
classifier_model.summary()
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0425 13:43:24.089348 140478929901376 saver.py:1483] Saver not created because there are no variables in the graph to restore
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 1001)              0
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________

# %%
image_data = image_generator.flow_from_directory(str(data_root), target_size=IMAGE_SIZE)
for image_batch,label_batch in image_data:
  print("Image batch shape: ", image_batch.shape)
  print("Label batch shape: ", label_batch.shape)
  break
# Out:
# Found 3670 images belonging to 5 classes.
# Image batch shape:  (32, 224, 224, 3)
# Label batch shape:  (32, 5)

# %%
import tensorflow.keras.backend as K
sess = K.get_session()
init = tf.global_variables_initializer()

sess.run(init)

# %%
print(IMAGE_SIZE)
# Out:
# [224, 224]

# %%
import numpy as np
import PIL.Image as Image

grace_hopper = tf.keras.utils.get_file('image.jpg','https://storage.googleapis.com/download.tensorflow.org/example_images/grace_hopper.jpg')
grace_hopper = Image.open(grace_hopper).resize(IMAGE_SIZE)
grace_hopper
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FC330098C88>

# %%
grace_hopper = np.array(grace_hopper)/255.0
grace_hopper.shape
# Out:
# (224, 224, 3)

# %%
result = classifier_model.predict(grace_hopper[np.newaxis, ...])
result.shape
# Out:
# (1, 1001)

# %%
predicted_class = np.argmax(result[0], axis=-1)
predicted_class
# Out:
# 653

# %%
labels_path = tf.keras.utils.get_file('ImageNetLabels.txt','https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')
imagenet_labels = np.array(open(labels_path).read().splitlines())

# %%
plt.imshow(grace_hopper)
plt.axis('off')
predicted_class_name = imagenet_labels[predicted_class]
_ = plt.title("Prediction: " + predicted_class_name)

# %%
result_batch = classifier_model.predict(image_batch)

# %%
labels_batch = imagenet_labels[np.argmax(result_batch, axis=-1)]
labels_batch
# Out:
# array(['picket fence', 'rapeseed', 'daisy', 'sea urchin', 'bubble', 'pot',
#        'vase', 'daisy', 'bicycle-built-for-two', 'velvet', 'daisy',
#        'groom', 'picket fence', 'daisy', 'daisy', 'cardoon', 'daisy',
#        'daisy', 'cardoon', 'daisy', 'daisy', 'barn spider', 'buckeye',
#        'cardoon', 'hummingbird', 'coil', 'grocery store', 'wool', 'daisy',
#        'mushroom', 'pinwheel', 'feather boa'], dtype='<U30')

# %%
plt.figure(figsize=(10,9))
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(image_batch[n])
  plt.title(labels_batch[n])
  plt.axis('off')
_ = plt.suptitle("ImageNet predictions")

# %% [markdown]
# ###### Transfer learning:

# %%
feature_extractor_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/2" #@param {type:"string"}
def feature_extractor(x):
  feature_extractor_module = hub.Module(feature_extractor_url)
  return feature_extractor_module(x)

IMAGE_SIZE = hub.get_expected_image_size(hub.Module(feature_extractor_url))

# %%
image_data = image_generator.flow_from_directory(str(data_root), target_size=IMAGE_SIZE)
for image_batch,label_batch in image_data:
  print("Image batch shape: ", image_batch.shape)
  print("Labe batch shape: ", label_batch.shape)
  break
# Out:
# Found 3670 images belonging to 5 classes.
# Image batch shape:  (32, 224, 224, 3)
# Labe batch shape:  (32, 5)

# %%
features_extractor_layer = layers.Lambda(feature_extractor, input_shape=IMAGE_SIZE+[3])
features_extractor_layer.trainable = False

# %%
model = tf.keras.Sequential([
  features_extractor_layer,
  layers.Dense(image_data.num_classes, activation='softmax')
])
model.summary()
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0425 17:37:00.194502 140478929901376 saver.py:1483] Saver not created because there are no variables in the graph to restore
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_2 (Lambda)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 6405
# =================================================================
# Total params: 6,405
# Trainable params: 6,405
# Non-trainable params: 0
# _________________________________________________________________

# %%
init = tf.global_variables_initializer()
sess.run(init)
result = model.predict(image_batch)
result.shape
# Out:
# (32, 5)

# %%
model.compile(
  optimizer=tf.train.AdamOptimizer(), 
  loss='categorical_crossentropy',
  metrics=['accuracy'])

# %%
class CollectBatchStats(tf.keras.callbacks.Callback):
  def __init__(self):
    self.batch_losses = []
    self.batch_acc = []
    
  def on_batch_end(self, batch, logs=None):
    self.batch_losses.append(logs['loss'])
    self.batch_acc.append(logs['acc'])

# %%
steps_per_epoch = image_data.samples//image_data.batch_size
batch_stats = CollectBatchStats()
model.fit((item for item in image_data), epochs=1, 
                    steps_per_epoch=steps_per_epoch,
                    callbacks = [batch_stats])
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# W0425 17:37:43.716331 140478929901376 deprecation.py:323] From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 114/114 [==============================] - 71s 619ms/step - loss: 0.6512 - acc: 0.7644

# %%
plt.figure()
plt.ylabel("Loss")
plt.xlabel("Training Steps")
plt.ylim([0,2])
plt.plot(batch_stats.batch_losses)

plt.figure()
plt.ylabel("Accuracy")
plt.xlabel("Training Steps")
plt.ylim([0,1])
plt.plot(batch_stats.batch_acc)

# %%
label_names = sorted(image_data.class_indices.items(), key=lambda pair:pair[1])
label_names = np.array([key.title() for key, value in label_names])
label_names
# Out:
# array(['Daisy', 'Dandelion', 'Roses', 'Sunflowers', 'Tulips'],
#       dtype='<U10')

# %%
result_batch = model.predict(image_batch)

labels_batch = label_names[np.argmax(result_batch, axis=-1)]
labels_batch
# Out:
# array(['Daisy', 'Tulips', 'Roses', 'Tulips', 'Dandelion', 'Dandelion',
#        'Dandelion', 'Dandelion', 'Sunflowers', 'Dandelion', 'Dandelion',
#        'Tulips', 'Daisy', 'Tulips', 'Sunflowers', 'Dandelion', 'Roses',
#        'Daisy', 'Sunflowers', 'Tulips', 'Tulips', 'Tulips', 'Roses',
#        'Dandelion', 'Roses', 'Daisy', 'Roses', 'Tulips', 'Dandelion',
#        'Dandelion', 'Daisy', 'Tulips'], dtype='<U10')

# %%
plt.figure(figsize=(10,9))
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(image_batch[n])
  plt.title(labels_batch[n])
  plt.axis('off')
_ = plt.suptitle("Model predictions")

# %%
export_path = tf.contrib.saved_model.save_keras_model(model, "./saved_models")
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0425 17:40:57.228007 140478929901376 saver.py:1483] Saver not created because there are no variables in the graph to restore
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-c8ef62589b19> in <module>
# ----> 1 export_path = tf.contrib.saved_model.save_keras_model(model, "./saved_models")
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/contrib/saved_model/python/saved_model/keras_saved_model.py in save_keras_model(model, saved_model_path, custom_objects, as_text, input_signature, serving_only)
#     136         signatures=training_utils.trace_model_call(model, input_signature))
#     137   else:
# --> 138     _save_v1_format(model, export_dir, custom_objects, as_text, input_signature)
#     139
#     140   try:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/contrib/saved_model/python/saved_model/keras_saved_model.py in _save_v1_format(model, path, custom_objects, as_text, input_signature)
#     205     # TODO(kathywu): Verify this works with v2 optimizer.
#     206     if isinstance(model.optimizer, optimizers.TFOptimizer):
# --> 207       _export_mode(model_fn_lib.ModeKeys.TRAIN, has_saved_vars, **export_args)
#     208       has_saved_vars = True
#     209       _export_mode(model_fn_lib.ModeKeys.EVAL, has_saved_vars, **export_args)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/contrib/saved_model/python/saved_model/keras_saved_model.py in _export_mode(mode, has_saved_vars, builder, model, custom_objects, checkpoint_path, input_signature)
#     280     train_op = None
#     281     if mode == model_fn_lib.ModeKeys.TRAIN:
# --> 282       clone._make_train_function()
#     283       train_op = clone.train_function.updates_op
#     284     elif mode == model_fn_lib.ModeKeys.EVAL:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _make_train_function(self)
#    1917     ]
#    1918     self._make_train_function_helper('train_function',
# -> 1919                                      [self.total_loss] + metrics_tensors)
#    1920
#    1921   def _make_fit_function(self):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _make_train_function_helper(self, fn_name, outputs, metric_updates)
#    1893             # Training updates
#    1894             updates = self.optimizer.get_updates(
# -> 1895                 params=self._collected_trainable_weights, loss=self.total_loss)
#    1896       # Unconditional updates
#    1897       updates += self.get_updates_for(None)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/optimizers.py in get_updates(self, loss, params)
#     761       grads = self.optimizer.compute_gradients(loss, params)
#     762       opt_update = self.optimizer.apply_gradients(
# --> 763           grads, global_step=self.iterations)
#     764
#     765     self.updates.append(opt_update)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/optimizer.py in apply_gradients(self, grads_and_vars, global_step, name)
#     593                        ([str(v) for _, v, _ in converted_grads_and_vars],))
#     594     with ops.init_scope():
# --> 595       self._create_slots(var_list)
#     596     update_ops = []
#     597     with ops.name_scope(name, self._name) as name:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/adam.py in _create_slots(self, var_list)
#     126     self._create_non_slot_variable(initial_value=self._beta1,
#     127                                    name="beta1_power",
# --> 128                                    colocate_with=first_var)
#     129     self._create_non_slot_variable(initial_value=self._beta2,
#     130                                    name="beta2_power",
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/optimizer.py in _create_non_slot_variable(self, initial_value, name, colocate_with)
#     833       # non-slot variables with the same name in different graphs, trying to
#     834       # save all of them would result in errors).
# --> 835       self._handle_deferred_dependencies(name=name, checkpointable=v)
#     836       self._non_slot_dict[key] = v
#     837
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/checkpointable/base.py in _handle_deferred_dependencies(self, name, checkpointable)
#     739         key=lambda restore: restore.checkpoint.restore_uid,
#     740         reverse=True):
# --> 741       checkpoint_position.restore(checkpointable)
#     742
#     743     # Pass on any name-based restores queued in this object.
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/checkpointable/base.py in restore(self, checkpointable)
#     195         # This object's correspondence with a checkpointed object is new, so
#     196         # process deferred restorations for it and its dependencies.
# --> 197         restore_ops = checkpointable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     198         if restore_ops:
#     199           self._checkpoint.new_restore_ops(restore_ops)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/checkpointable/base.py in _restore_from_checkpoint_position(self, checkpoint_position)
#     762           ._single_restoration_from_checkpoint_position(
#     763               checkpoint_position=current_position,
# --> 764               visit_queue=visit_queue)))
#     765     return restore_ops
#     766
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/checkpointable/base.py in _single_restoration_from_checkpoint_position(self, checkpoint_position, visit_queue)
#     774     # restoration on to our dependencies.
#     775     if checkpoint.restore_uid > self._update_uid:
# --> 776       restore_ops = checkpoint_position.restore_ops()
#     777       self._update_uid = checkpoint.restore_uid
#     778     else:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/checkpointable/base.py in restore_ops(self)
#     377      python_saveables) = self._gather_ops_or_named_saveables()
#     378     restore_ops.extend(self._checkpoint.restore_saveables(
# --> 379         tensor_saveables, python_saveables))
#     380     return restore_ops
#     381
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/checkpointable/util.py in restore_saveables(self, tensor_saveables, python_saveables)
#     191                     [spec.slice_spec],
#     192                     [spec.dtype])[0])
# --> 193           restore_op = saveable.restore(tensors, restored_shapes=None)
#     194         if not context.executing_eagerly():
#     195           assert saveable.name not in self.restore_ops_by_name
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/saving/saveable_object_util.py in restore(self, restored_tensors, restored_shapes)
#     113       restored_tensor = array_ops.identity(restored_tensor)
#     114       return resource_variable_ops.shape_safe_assign_variable_handle(
# --> 115           self.handle_op, self._var_shape, restored_tensor)
#     116
#     117
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py in shape_safe_assign_variable_handle(handle, shape, value, name)
#     158   return gen_resource_variable_ops.assign_variable_op(handle,
#     159                                                       value_tensor,
# --> 160                                                       name=name)
#     161
#     162
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py in assign_variable_op(resource, value, name)
#     182   # Add nodes to the TensorFlow graph.
#     183   _, _, _op = _op_def_lib._apply_op_helper(
# --> 184         "AssignVariableOp", resource=resource, value=value, name=name)
#     185   return _op
#     186   _result = None
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     348       # Need to flatten all the arguments into a list.
#     349       # pylint: disable=protected-access
# --> 350       g = ops._get_graph_from_inputs(_Flatten(keywords.values()))
#     351       # pylint: enable=protected-access
#     352     except AssertionError as e:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _get_graph_from_inputs(op_input_list, graph)
#    5711         graph = graph_element.graph
#    5712       elif original_graph_element is not None:
# -> 5713         _assert_same_graph(original_graph_element, graph_element)
#    5714       elif graph_element.graph is not graph:
#    5715         raise ValueError("%s is not from the passed-in graph." % graph_element)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _assert_same_graph(original_item, item)
#    5647   if original_item.graph is not item.graph:
#    5648     raise ValueError("%s must be from the same graph as %s." % (item,
# -> 5649                                                                 original_item))
#    5650
#    5651
#
# ValueError: Tensor("Identity_263:0", dtype=float32) must be from the same graph as Tensor("training/TFOptimizer/beta1_power:0", shape=(), dtype=resource).

# %%
export_path
# Out:
# b'./saved_models/1556214027'
